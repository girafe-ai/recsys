# %% [markdown]
# ## Seminar 4: Recommendations analysis

# %%
# !pip install implicit
# !pip install gdown
# Out:
# Requirement already satisfied: implicit in /usr/local/lib/python3.11/dist-packages (0.7.2)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from implicit) (2.0.2)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.11/dist-packages (from implicit) (1.14.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from implicit) (4.67.1)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.11/dist-packages (from implicit) (3.6.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import random
import zipfile
from collections import defaultdict
from typing import List, Tuple

import gdown
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.sparse as sp
import seaborn as sns
from implicit.als import AlternatingLeastSquares
from implicit.nearest_neighbours import (BM25Recommender, ItemItemRecommender,
                                         bm25_weight)
from scipy.sparse import csr_matrix
from sklearn.metrics import jaccard_score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm

# %% [markdown]
# ### 1. Download dataset

# %% [markdown]
# Today we will use Amazon dataset for phones and accessories.

# %%
file_id = "1p0aZWKnMenXB6t7LUfUUsI5ICci37P03"
destination = "amazon.zip"
download_url = f"https://drive.google.com/uc?id={file_id}"

gdown.download(download_url, destination, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1p0aZWKnMenXB6t7LUfUUsI5ICci37P03
# From (redirected): https://drive.google.com/uc?id=1p0aZWKnMenXB6t7LUfUUsI5ICci37P03&confirm=t&uuid=97ec8126-68aa-4d23-a931-0191cfb46062
# To: /content/amazon.zip
# 100%|██████████| 548M/548M [00:07<00:00, 72.5MB/s]
# 'amazon.zip'

# %%
with zipfile.ZipFile(destination, "r") as zip_ref:
    zip_ref.extractall("amazon")

# %% [markdown]
# ### 2. EDA

# %%
ratings = (
    pd.read_csv(
        "amazon/Amazon_Cell_Phones_and_Accessories/Amazon_Cell_Phones_and_Accessories.inter",
        sep="\t",
        names=["user_id", "item_id", "rating", "ts"],
        header=0,
    )
    .sample(100_000)
    .reset_index(drop=True)
)

# %%
ratings.head()
# Out:
#                         user_id     item_id  rating             ts
# 0  AFDM2KJN34XJ7HZGMSY55KGCD3SQ  B017FZXEOG     3.0  1470337570000
# 1  AGPLRU3BLAN6EDXBEW6TDOUOPBRQ  B0B9YMYM68     5.0  1671717960807
# 2  AFF5VSHO5FLEUVXJND3MHJ6ZUFUQ  B0006JI3LI     4.0  1210583690000
# 3  AFJOOPSKCIZ6YXK6WDP7GN6POFMA  B08MV884LH     5.0  1612388494452
# 4  AGC2DZQRZXP526HACZOZRHETY4IA  B01N6RHNUX     5.0  1519767615346

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   user_id  100000 non-null  object
#  1   item_id  100000 non-null  object
#  2   rating   100000 non-null  float64
#  3   ts       100000 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.1+ MB

# %%
items_data = pd.read_csv(
    "amazon/Amazon_Cell_Phones_and_Accessories/Amazon_Cell_Phones_and_Accessories.item",
    sep="\t",
    names=["item_id", "categories", "average_rating", "rating_number", "price"],
    header=0,
)

# %%
items_data.head()
# Out:
#       item_id                                         categories  \
# 0  B013SK1JTY  Cell Phones & Accessories,Cases, Holsters & Sl...
# 1  B07ZPSG8P5  Cell Phones & Accessories,Cases, Holsters & Sl...
# 2  B00GKR3L12       Cell Phones & Accessories,iPhone Accessories
# 3  B00PB8U8BW       Cell Phones & Accessories,iPhone Accessories
# 4  B07D3RHSRV  Cell Phones & Accessories,Cases, Holsters & Sl...
#
#    average_rating  rating_number  price
# 0             3.8              5    NaN
# 1             4.4            177  11.98
# 2             4.0              2    NaN
# 3             4.0             15    NaN
# 4             4.0              1    NaN

# %%
items_data.loc[0]["categories"]
# Out:
# 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases'

# %%
items_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1288441 entries, 0 to 1288440
# Data columns (total 5 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   item_id         1288441 non-null  object
#  1   categories      1288441 non-null  object
#  2   average_rating  1288441 non-null  float64
#  3   rating_number   1288441 non-null  int64
#  4   price           252090 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 49.2+ MB

# %%
joined = pd.merge(ratings, items_data, on="item_id", how="inner")

# %%
def ids_encoder(ratings, items_data):

    ratings["user_id"] = ratings["user_id"].astype(str)
    ratings["item_id"] = ratings["item_id"].astype(str)
    items_data["item_id"] = items_data["item_id"].astype(str)

    users = sorted(ratings["user_id"].unique())
    items = sorted(ratings["item_id"].unique())

    # create users and items encoders
    uencoder = LabelEncoder()
    iencoder = LabelEncoder()

    # fit users and items ids to the corresponding encoder
    uencoder.fit(users)
    iencoder.fit(items)

    items_data = items_data[items_data["item_id"].isin(iencoder.classes_)]

    # encode userids and itemids
    ratings.user_id = uencoder.transform(ratings.user_id.tolist())
    ratings.item_id = iencoder.transform(ratings.item_id.tolist())
    items_data.item_id = iencoder.transform(items_data.item_id.tolist())

    return ratings, items_data, uencoder, iencoder


ratings, items_data, uencoder, iencoder = ids_encoder(ratings, items_data)
# Out:
# <ipython-input-57-0dbfc19d6bf1>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   items_data.item_id = iencoder.transform(items_data.item_id.tolist())

# %%
ratings_cnt = (
    ratings.groupby("rating")["user_id"].count().rename("cnt_users").reset_index()
)
plt.barh(ratings_cnt.rating, ratings_cnt.cnt_users, color="royalblue")
plt.title("Overall Count of Ratings", fontsize=10)
plt.xlabel("Count", fontsize=10)
plt.ylabel("Rating", fontsize=10)
plt.grid()
plt.show()

# %%
user_item_counts = ratings.groupby("item_id")["user_id"].count().values

# Plot the histogram
plt.figure(figsize=(10, 6))
ax = sns.histplot(user_item_counts, bins=20, log_scale=True)
ax.set(
    xlabel="Number of users",
    ylabel="Number of items",
    title="User-item interactions count",
)
ax.grid()

# %% [markdown]
# ### 3. Fit algorithms

# %% [markdown]
# Firstly, let's create csr matrix and user, item mappings.

# %%
def get_coo_matrix(
    interactions,
    users_mapping,
    items_mapping,
    user_col="user_id",
    item_col="item_id",
    weight_col=None,
):
    if weight_col is None:
        weights = np.ones(len(interactions), dtype=np.float32)
    else:
        weights = interactions[weight_col].astype(np.float32)

    interaction_matrix = sp.coo_matrix(
        (
            weights,
            (
                interactions[user_col].map(users_mapping.get),
                interactions[item_col].map(items_mapping.get),
            ),
        )
    )
    return interaction_matrix


def make_mapping(data):
    return {v: k for k, v in enumerate(data)}

# %%
items_mapping = make_mapping(items_data["item_id"].unique())
users_mapping = make_mapping(ratings["user_id"].unique())

items_inv_mapping = dict({(v, k) for k, v in items_mapping.items()})

# %%
interactions_matrix = get_coo_matrix(
    ratings, users_mapping=users_mapping, items_mapping=items_mapping
).tocsr()

# %%
interactions_matrix_f64 = interactions_matrix.astype("float64")

# %% [markdown]
# #### i2i model

# %%
i2i_model = ItemItemRecommender(K=10)
i2i_model.fit(interactions_matrix_f64)
# Out:
#   0%|          | 0/56763 [00:00<?, ?it/s]

# %%
top_n = 50
total_preds_i2i = {}
for user in tqdm(ratings["user_id"].unique()):
    preds = i2i_model.recommend(
        user, interactions_matrix[user], N=top_n, filter_already_liked_items=False
    )
    preds_ids = preds[0]
    preds = [items_inv_mapping[item_id] for item_id in preds_ids]

    total_preds_i2i[user] = preds
# Out:
# 100%|██████████| 99422/99422 [00:08<00:00, 11049.46it/s]

# %%
for item in tqdm(items_data["item_id"]):
    sim_items = i2i_model.similar_items(item)
    # break
# Out:
# 100%|██████████| 56763/56763 [00:09<00:00, 6193.21it/s]

# %% [markdown]
# #### ALS model:

# %%
als_model = AlternatingLeastSquares(factors=10, regularization=0.01, iterations=20)
als_model.fit(interactions_matrix, show_progress=True)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
top_n = 200
total_preds_als = {}
for user in tqdm(ratings["user_id"].unique()):
    preds = als_model.recommend(
        user, interactions_matrix[user], N=top_n, filter_already_liked_items=True
    )
    preds_ids = preds[0]
    preds = [items_inv_mapping[item_id] for item_id in preds_ids]

    total_preds_als[user] = preds
# Out:
# 100%|██████████| 99422/99422 [01:15<00:00, 1323.59it/s]

# %%
total_preds = {}
for user_id, als_vals in tqdm(total_preds_als.items()):
    i2i_vals = total_preds_i2i[user_id]
    total_preds[user_id] = list(set(np.append(als_vals, i2i_vals)))
# Out:
# 100%|██████████| 99422/99422 [00:06<00:00, 15668.36it/s]

# %%
joined_recs = pd.merge(ratings, items_data, on="item_id", how="inner")

# %%
joined_recs
# Out:
#        user_id  item_id  rating             ts  \
# 0        32237    14318     3.0  1470337570000
# 1        66580    53123     5.0  1671717960807
# 2        33466       47     4.0  1210583690000
# 3        36973    43711     5.0  1612388494452
# 4        56016    20383     5.0  1519767615346
# ...        ...      ...     ...            ...
# 99995    66546     1209     1.0  1383574653000
# 99996    10302    56046     5.0  1687012069788
# 99997    42548    29559     5.0  1549475442963
# 99998      807    55632     1.0  1666861855944
# 99999    58446    41558     5.0  1604355899488
#
#                                               categories  average_rating  \
# 0      Cell Phones & Accessories,Cases, Holsters & Sl...             4.1
# 1      Cell Phones & Accessories,Cases, Holsters & Sl...             4.4
# 2      Cell Phones & Accessories,Accessories,Automobi...             3.8
# 3      Cell Phones & Accessories,Cases, Holsters & Sl...             4.5
# 4      Cell Phones & Accessories,Accessories,Cables &...             3.8
# ...                                                  ...             ...
# 99995  Cell Phones & Accessories,Accessories,Maintena...             4.2
# 99996  Cell Phones & Accessories,Cases, Holsters & Sl...             4.0
# 99997  Cell Phones & Accessories,Cases, Holsters & Sl...             4.4
# 99998  Cell Phones & Accessories,Accessories,Chargers...             4.5
# 99999  Cell Phones & Accessories,Cases, Holsters & Sl...             4.0
#
#        rating_number  price
# 0                312    NaN
# 1                  9   9.95
# 2                 56  30.09
# 3               5800  23.99
# 4                 11    NaN
# ...              ...    ...
# 99995            182    NaN
# 99996            285  27.98
# 99997            342    NaN
# 99998          19284   7.99
# 99999             51    NaN
#
# [100000 rows x 8 columns]

# %%
items_with_categories = {}
for row in joined_recs[["item_id", "categories"]].values.tolist():
    items_with_categories[row[0]] = row[1]

# %%
items_with_categories
# Out:
# {14318: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  53123: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Armbands',
#  47: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  43711: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  20383: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  54021: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  38968: 'Cell Phones & Accessories,Accessories,Adhesive Card Holders',
#  44810: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  24278: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  34247: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  21406: 'Cell Phones & Accessories',
#  48500: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  574: 'Cell Phones & Accessories,Wireless Trade-In',
#  9349: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  52858: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cables & Chargers',
#  53398: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  26556: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Tripods',
#  33354: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  11836: 'Cell Phones & Accessories',
#  52638: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  2988: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  18301: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  9432: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  45864: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  24208: 'Cell Phones & Accessories,Accessories',
#  36838: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  33816: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  55534: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  25237: 'Cell Phones & Accessories',
#  47180: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  39196: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  8635: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  1831: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Unlocked Wireless Trade-In',
#  43376: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  30950: 'Cell Phones & Accessories',
#  22359: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  27833: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  29288: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  12373: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  21173: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters',
#  34625: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  46653: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  55769: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Tripods',
#  22717: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  55632: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  56383: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  56647: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  17832: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  40369: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts',
#  11774: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  39711: 'Cell Phones & Accessories,Accessories,Stands',
#  32975: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  4141: 'Cell Phones & Accessories',
#  11364: 'Cell Phones & Accessories',
#  12510: 'Cell Phones & Accessories,iPhone Accessories',
#  55962: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases',
#  53691: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  4947: 'Cell Phones & Accessories,Cell Phones',
#  11538: 'Cell Phones & Accessories',
#  56656: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Screen Protectors',
#  14088: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  27361: 'Cell Phones & Accessories',
#  44735: 'Cell Phones & Accessories,Accessories,Single Ear Bluetooth Headsets',
#  19647: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  55417: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Sleeves',
#  31604: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  38196: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  16099: 'Cell Phones & Accessories',
#  47419: 'Cell Phones & Accessories,Wireless Trade-In',
#  30600: 'Cell Phones & Accessories,Big Savings on Tile',
#  9585: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  42006: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  27033: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  56057: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  7737: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  38826: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  7243: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  12477: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Tripods',
#  51591: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  55560: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  5249: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  41181: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Flashes & Selfie Lights',
#  17616: 'Cell Phones & Accessories',
#  55983: 'Cell Phones & Accessories,Accessories,Grips',
#  49449: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  55787: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  18207: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  5956: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  43659: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  53612: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  43868: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases',
#  13160: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  1566: 'Cell Phones & Accessories',
#  47753: 'Cell Phones & Accessories,Accessories,Stands',
#  51637: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  2259: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  9102: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  8281: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  12651: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  25764: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  50800: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Tripods',
#  12771: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  15276: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  26713: 'Cell Phones & Accessories',
#  5804: 'Cell Phones & Accessories,iPhone Accessories',
#  26215: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  11657: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  23742: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  19172: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cables & Chargers',
#  12911: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  19423: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  32570: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  20650: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  15914: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  43300: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  53785: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  23339: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  42730: 'Cell Phones & Accessories',
#  21355: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  30620: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts,Batteries',
#  48047: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  20411: 'Cell Phones & Accessories',
#  36035: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  25434: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  56019: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  45805: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  11008: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Carrier Branded Wireless Trade-In',
#  26264: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Screen Protectors',
#  355: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  50182: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  55595: 'Cell Phones & Accessories,Accessories,Signal Boosters',
#  24366: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  40017: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  10648: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters',
#  37940: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  47946: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Flashes & Selfie Lights',
#  6661: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  43753: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  29137: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  35524: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  9430: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  23450: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  30755: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  49106: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  51091: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  36842: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  23542: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  55048: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  6539: 'Cell Phones & Accessories,iPhone Accessories',
#  16673: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  20203: 'Cell Phones & Accessories',
#  40327: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  45921: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  10591: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  12618: 'Cell Phones & Accessories',
#  34372: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  47683: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  34664: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  45925: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  50158: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  46414: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  38942: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  32230: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  43909: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  30131: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  25988: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  52560: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters',
#  42544: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  6312: 'Cell Phones & Accessories,Accessories,Cables & Adapters,OTG Adapters',
#  18153: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  43814: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Bumpers',
#  27063: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  16418: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts',
#  186: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Unlocked Wireless Trade-In',
#  1701: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Unlocked Wireless Trade-In',
#  24520: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  45000: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  51751: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cables & Chargers',
#  15048: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  45349: 'Cell Phones & Accessories',
#  52730: 'Cell Phones & Accessories',
#  20777: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  31141: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  34142: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  36438: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  21630: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  32244: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  34975: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  23111: 'Cell Phones & Accessories,Cell Phones',
#  54066: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  11227: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  47272: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  19925: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  47745: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  54018: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  2423: 'Cell Phones & Accessories,iPhone Accessories',
#  49766: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  39342: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  19609: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  38675: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  4053: 'Cell Phones & Accessories',
#  39587: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  11281: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  31413: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  25445: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Handheld Gimbals & Stabilizers',
#  33221: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Battery Charger Cases',
#  27807: 'Cell Phones & Accessories',
#  8695: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  11561: 'Cell Phones & Accessories,Accessories,Single Ear Bluetooth Headsets',
#  55241: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  51557: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  28586: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  28477: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  54624: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  55607: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  26049: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  38990: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  4069: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Dry Bags',
#  46939: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  35014: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases',
#  50119: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  26340: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  54571: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  35747: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  41358: 'Cell Phones & Accessories,Accessories,Stands',
#  56729: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Flashes & Selfie Lights,Selfie Lights',
#  37510: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  41663: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  36432: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  17233: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  14128: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Unlocked Wireless Trade-In',
#  24252: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  119: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts',
#  22498: 'Cell Phones & Accessories,Cell Phones',
#  40148: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  56397: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  252: 'Cell Phones & Accessories,Accessories,Single Ear Bluetooth Headsets',
#  18665: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  31218: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  33179: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  53122: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  32621: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  6728: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  4456: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs',
#  44214: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  47755: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts,Screens',
#  16863: 'Cell Phones & Accessories',
#  35045: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  38908: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  32865: 'Cell Phones & Accessories,Accessories,Stands',
#  56757: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Solar Chargers',
#  38224: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  13332: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  36025: 'Cell Phones & Accessories',
#  55268: 'Cell Phones & Accessories,Accessories,Grips',
#  19397: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  47694: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  50769: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  5: 'Cell Phones & Accessories,Accessories',
#  35713: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  39840: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  4544: 'Cell Phones & Accessories',
#  20850: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  50333: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  32516: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  26138: 'Cell Phones & Accessories,V4 Customers Keep It - 30%',
#  50193: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  53753: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  10874: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  28091: 'Cell Phones & Accessories,iPhone Accessories',
#  18013: 'Cell Phones & Accessories,Accessories,Single Ear Bluetooth Headsets',
#  14704: 'Cell Phones & Accessories',
#  10335: 'Cell Phones & Accessories',
#  32582: 'Cell Phones & Accessories',
#  21463: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  16693: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  52001: 'Cell Phones & Accessories,Accessories,Signal Boosters',
#  4278: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Unlocked Wireless Trade-In',
#  17494: 'Cell Phones & Accessories,Accessories',
#  38530: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  55920: 'Cell Phones & Accessories,Accessories',
#  44601: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  13094: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  34479: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  34089: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  39065: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  41971: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  44072: 'Cell Phones & Accessories',
#  18637: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  17902: 'Cell Phones & Accessories,Accessories,Virtual Reality (VR) Headsets',
#  21187: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  45397: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  55224: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  53272: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  18751: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  8199: 'Cell Phones & Accessories,Accessories',
#  6108: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  48004: 'Cell Phones & Accessories,Accessories,Single Ear Bluetooth Headsets',
#  3954: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  50575: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  6847: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  8630: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  15310: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  42037: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts,Screens',
#  29238: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  42380: 'Cell Phones & Accessories',
#  33736: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Screen Protectors',
#  46888: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  7290: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  17272: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  599: 'Cell Phones & Accessories,iPhone Accessories',
#  8138: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  28482: 'Cell Phones & Accessories,SIM Cards & Prepaid Minutes,SIM Cards',
#  50618: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  38916: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  10503: 'Cell Phones & Accessories,Accessories',
#  9042: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  36988: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  27668: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases',
#  32062: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  37372: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Battery Charger Cases',
#  56561: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  18903: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  49075: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  48033: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  12624: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  28041: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  54195: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  37157: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  28316: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  43410: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  50545: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Flashes & Selfie Lights,Selfie Lights',
#  19852: 'Cell Phones & Accessories',
#  18376: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  44083: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases',
#  2708: 'Cell Phones & Accessories,Accessories',
#  101: 'Cell Phones & Accessories,Accessories',
#  54668: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  916: 'Cell Phones & Accessories',
#  867: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  16987: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  43484: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  43466: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  53606: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  45390: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  42467: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  52039: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Dry Bags',
#  44879: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  48852: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  2722: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  26803: 'Cell Phones & Accessories,Accessories',
#  32191: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  9381: 'Cell Phones & Accessories,Accessories',
#  4745: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  32694: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  747: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  16232: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  43980: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  40793: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  28917: 'Cell Phones & Accessories,Accessories,Stands',
#  4890: 'Cell Phones & Accessories',
#  31935: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  41260: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  24616: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  44233: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  31070: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  16759: 'Cell Phones & Accessories,SIM Cards & Prepaid Minutes,SIM Cards',
#  1243: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  29055: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  34153: 'Cell Phones & Accessories,Accessories',
#  17459: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  16998: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  15265: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  50327: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  45630: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  8324: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  12674: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  7367: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  34564: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  21533: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  5543: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Carrier Branded Wireless Trade-In',
#  22876: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  20036: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  9560: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  55521: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  45622: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  18765: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  29852: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Screen Protectors',
#  26180: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Screen Protectors',
#  13341: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  44868: 'Cell Phones & Accessories,Accessories,Stands',
#  7756: 'Cell Phones & Accessories',
#  26302: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  49715: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  20563: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Dry Bags',
#  16369: 'Cell Phones & Accessories',
#  8744: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  30035: 'Cell Phones & Accessories,iPhone Accessories',
#  40931: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  12705: 'Cell Phones & Accessories,iPhone Accessories',
#  5329: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  14855: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  56117: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts,Batteries',
#  26722: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  54234: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  52168: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  53738: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  54014: 'Cell Phones & Accessories,Accessories,Décor',
#  56541: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  15817: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  51590: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases',
#  230: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  11665: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  26052: 'Cell Phones & Accessories,Accessories,Stands',
#  28978: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  25738: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  42965: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  15352: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  52021: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cables & Chargers',
#  633: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  18294: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  42378: 'Cell Phones & Accessories,Accessories,Grips',
#  48820: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cables & Chargers',
#  49711: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  13287: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  26354: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  1345: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Speakerphones',
#  32438: 'Cell Phones & Accessories',
#  49756: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  17941: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  23376: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  33240: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  47015: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  10538: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  14209: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  19457: 'Cell Phones & Accessories,Accessories,Single Ear Bluetooth Headsets',
#  48146: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Battery Charger Cases',
#  3406: 'Cell Phones & Accessories,iPhone Accessories',
#  52196: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  54336: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  34037: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  36087: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  4829: 'Cell Phones & Accessories',
#  51886: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  13670: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  3640: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  4256: 'Cell Phones & Accessories',
#  23133: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  41214: 'Cell Phones & Accessories',
#  55753: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  50176: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  23862: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Battery Charger Cases',
#  8810: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  5671: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  24515: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  45637: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  12732: 'Cell Phones & Accessories,Accessories',
#  24186: 'Cell Phones & Accessories,Cell Phones',
#  49367: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  9499: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  1927: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  38655: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases',
#  7875: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  3999: 'Cell Phones & Accessories',
#  16516: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Carrier Branded Wireless Trade-In',
#  55250: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  52856: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  36250: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  9110: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  38599: 'Cell Phones & Accessories',
#  24738: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  40593: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  55547: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  46314: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  5807: 'Cell Phones & Accessories,iPhone Accessories',
#  55394: 'Cell Phones & Accessories,Accessories,Stands',
#  360: 'Cell Phones & Accessories,V4 Customers Keep It - 30%',
#  54821: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  21170: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  36247: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  21377: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  27590: 'Cell Phones & Accessories',
#  34182: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  50126: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  19386: 'Cell Phones & Accessories',
#  55149: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  55845: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Screen Protectors',
#  2621: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  46409: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  55788: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  26856: 'Cell Phones & Accessories',
#  46031: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  46182: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  18540: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cables & Chargers',
#  18313: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  26813: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  25524: 'Cell Phones & Accessories',
#  28723: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  31187: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  51501: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  52725: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  17416: 'Cell Phones & Accessories',
#  51553: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  18930: 'Cell Phones & Accessories,iPhone Accessories',
#  2582: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  2694: 'Cell Phones & Accessories',
#  5788: 'Cell Phones & Accessories,iPhone Accessories',
#  2451: 'Cell Phones & Accessories,iPhone Accessories',
#  3009: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Speakerphones',
#  10050: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  6371: 'Cell Phones & Accessories',
#  34641: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  21233: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  47436: 'Cell Phones & Accessories,Accessories,Single Ear Bluetooth Headsets',
#  7319: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  31592: 'Cell Phones & Accessories,Accessories,Stands',
#  5200: 'Cell Phones & Accessories',
#  32761: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  55459: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Crossbody & Lanyard Cases',
#  55202: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  57: 'Cell Phones & Accessories,Accessories,Stands',
#  11802: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  3430: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  23762: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Unlocked Wireless Trade-In',
#  14895: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  13917: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  23686: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  39222: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  6548: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  6740: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Unlocked Wireless Trade-In',
#  4226: 'Cell Phones & Accessories',
#  17987: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Armbands',
#  53745: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  5673: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  52205: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases',
#  26496: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  24880: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  49114: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  23599: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  23625: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  48836: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  10309: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Lens Attachments',
#  50614: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  45267: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  33368: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  12472: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  47073: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  29075: 'Cell Phones & Accessories',
#  53977: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  14888: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  16603: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  16629: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts',
#  29378: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  39505: 'Cell Phones & Accessories,Wireless Trade-In',
#  8437: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  8514: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  3354: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  47742: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  8529: 'Cell Phones & Accessories,Accessories',
#  3046: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs',
#  13442: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  22145: 'Cell Phones & Accessories',
#  28788: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Screen Protectors',
#  1610: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  16736: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  16899: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  18001: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Lens Attachments',
#  52304: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  51456: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  20788: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  7096: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  10516: 'Cell Phones & Accessories,Accessories',
#  25069: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  36600: 'Cell Phones & Accessories,Accessories',
#  28003: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Crossbody & Lanyard Cases',
#  12131: 'Cell Phones & Accessories',
#  17239: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts',
#  27347: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  41781: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  7156: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  25709: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  31945: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  8853: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  35095: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  34180: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  29614: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  40530: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  7041: 'Cell Phones & Accessories',
#  35601: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases',
#  42727: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  31771: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  41871: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  44335: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  22239: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  29390: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  942: 'Cell Phones & Accessories,iPhone Accessories',
#  13042: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  9779: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  54946: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  18956: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  12813: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  56654: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  45587: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  26549: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  26384: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  43128: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  45551: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  54822: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  6843: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  18533: 'Cell Phones & Accessories,Accessories,Lanyards & Wrist Straps',
#  10051: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  8098: 'Cell Phones & Accessories,Accessories',
#  19460: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  51801: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  42813: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  38853: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts,Screens',
#  5330: 'Cell Phones & Accessories',
#  4682: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  3822: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  33602: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cables & Chargers',
#  13765: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  26020: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  49629: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  55488: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  20111: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  30031: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
# ...
#  41669: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  32880: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  4004: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  54144: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  51518: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  56589: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  54781: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  25144: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  40573: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  53447: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  47423: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  5794: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  13653: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  56182: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  15325: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  9697: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  51622: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  46102: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  15924: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  12935: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  2272: 'Cell Phones & Accessories',
#  42997: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  26608: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  21130: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  49730: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts',
#  12691: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  39952: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  8982: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  28542: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  23995: 'Cell Phones & Accessories,Accessories,Cables & Adapters,OTG Adapters',
#  30024: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  13793: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  38116: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  19297: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  26207: 'Cell Phones & Accessories,Accessories,Stands',
#  54645: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  54734: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  39694: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  8571: 'Cell Phones & Accessories,Cases, Holsters & Sleeves',
#  56370: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  28708: 'Cell Phones & Accessories',
#  6828: 'Cell Phones & Accessories,Accessories',
#  45993: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  36029: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  55573: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  23046: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  43218: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  54063: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  49940: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  13685: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  45668: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  35559: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  49989: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  36571: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  31575: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  196: 'Cell Phones & Accessories,Cell Phones',
#  29513: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  48211: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  40934: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  23433: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  46913: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  29313: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  9663: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Unlocked Wireless Trade-In',
#  56374: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  30051: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  6408: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  4104: 'Cell Phones & Accessories,iPhone Accessories',
#  34799: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases',
#  10852: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Tripods',
#  8408: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  28711: 'Cell Phones & Accessories,Accessories',
#  52905: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  11788: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  37049: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  56100: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  51340: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  11071: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  46779: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  25374: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  45965: 'Cell Phones & Accessories,Wireless Trade-In',
#  7611: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  18424: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  46270: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  27716: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  6930: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  54817: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  43331: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  24260: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Battery Charger Cases',
#  45325: 'Cell Phones & Accessories',
#  31600: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  21044: 'Cell Phones & Accessories,iPhone Accessories',
#  24804: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  3167: 'Cell Phones & Accessories,Accessories',
#  24816: 'Cell Phones & Accessories',
#  28571: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  19024: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  52436: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Charging Stations',
#  11224: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Carrier Branded Wireless Trade-In',
#  46877: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  22160: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts,Batteries',
#  15245: 'Cell Phones & Accessories',
#  42672: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  10691: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  47769: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  18381: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Replacement Parts',
#  21931: 'Cell Phones & Accessories',
#  15480: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  52977: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  17081: 'Cell Phones & Accessories',
#  15689: 'Cell Phones & Accessories,Accessories,Stands',
#  5040: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  28109: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  47023: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  50540: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  55515: 'Cell Phones & Accessories,Accessories,Stands',
#  18095: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  31631: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  34165: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  29610: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  22664: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  22737: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  29928: 'Cell Phones & Accessories,iPhone Accessories',
#  39805: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  2596: 'Cell Phones & Accessories',
#  23434: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  51855: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  20701: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  28721: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Flashes & Selfie Lights,Selfie Lights',
#  52860: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  18323: 'Cell Phones & Accessories,Accessories,Cables & Adapters',
#  27172: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  10407: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  15375: 'Cell Phones & Accessories,Accessories',
#  14077: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  52128: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Dry Bags',
#  40784: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  24506: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  23362: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  9228: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Repair Kits',
#  34833: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Holsters',
#  42803: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  46736: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Portable Power Banks',
#  23387: 'Cell Phones & Accessories',
#  4902: 'Cell Phones & Accessories,Accessories',
#  23171: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  38278: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  2973: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  23715: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases with Band',
#  19635: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  9386: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  51246: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  22132: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  32400: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  26611: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  34809: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  56201: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  47084: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Bands',
#  5600: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  14388: 'Cell Phones & Accessories',
#  16318: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Lens Attachments',
#  30939: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Armbands',
#  29269: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  38906: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  32381: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Flip Cases',
#  3393: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  15083: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  4742: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  20376: 'Cell Phones & Accessories,Cell Phones',
#  47420: 'Cell Phones & Accessories,Wireless Trade-In',
#  48751: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  45427: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  3415: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  16800: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  24763: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  56413: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  5239: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  677: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  23375: 'Cell Phones & Accessories,Accessories,Grips',
#  16541: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  39011: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wall Chargers',
#  46682: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  24220: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  23382: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  23130: 'Cell Phones & Accessories,Accessories,Photo & Video Accessories,Lens Attachments',
#  13449: 'Cell Phones & Accessories',
#  22795: 'Cell Phones & Accessories,Accessories,Stands',
#  30714: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  47603: 'Cell Phones & Accessories',
#  47778: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  50310: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  9841: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  52484: 'Cell Phones & Accessories,Accessories,Smartwatch Accessories,Smartwatch Cases',
#  44581: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  13224: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  29961: 'Cell Phones & Accessories,Accessories,Maintenance, Upkeep & Repairs,Screen Protectors',
#  16501: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  47096: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Automobile Chargers',
#  56504: 'Cell Phones & Accessories,Accessories,Automobile Accessories,Cradles',
#  21425: 'Cell Phones & Accessories',
#  41257: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  53383: 'Cell Phones & Accessories,Accessories,Chargers & Power Adapters,Wireless Chargers',
#  1996: 'Cell Phones & Accessories',
#  35041: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  10101: 'Cell Phones & Accessories,Wireless Trade-In Buy Box Widget,Unlocked Wireless Trade-In',
#  46624: 'Cell Phones & Accessories,Accessories,Stylus Pens',
#  16582: 'Cell Phones & Accessories,Cases, Holsters & Sleeves,Basic Cases',
#  ...}

# %% [markdown]
# ### 4. Calculation of NDCG

# %% [markdown]
# $$
# \text{NDCG@K} = \frac{\text{DCG@K}}{\text{IDCG@K}}
# $$
#
# where:
#
# 1. **DCG@K** (Discounted Cumulative Gain) is given by:
#    $$
#    \text{DCG@K} = \sum_{i=1}^{K} \frac{\text{rel}_i}{\log_2(i+1)}
#    $$
#    Here, $\text{rel}_i$ is the relevance score of the item at position \( i \) in the ranked list.
#
# 2. **IDCG@K** (Ideal DCG) is the maximum possible DCG at \( K \) and is computed by sorting all items by their true relevance scores.
#
# In practice, **NDCG@K** values range between 0 and 1, where 1 indicates a perfect ranking according to true relevance.

# %%
def get_actual_relevant_items(ratings, user_id, top_k=10):
    # Filter items by the highest ratings for a given user
    user_ratings = ratings[ratings["user_id"] == user_id]
    highest_rated_items = user_ratings.sort_values(by="rating", ascending=False)[
        "item_id"
    ].head(top_k)
    return set(highest_rated_items)


def dcg(relevance_scores, top_n):
    """Calculate the Discounted Cumulative Gain (DCG) for the relevance scores up to top_n."""
    relevance_scores = np.array(relevance_scores)[:top_n]
    return np.sum(relevance_scores / np.log2(np.arange(2, len(relevance_scores) + 2)))


def ndcg(recommended_items, actual_relevant_items, top_n=10):
    """
    Calculate the NDCG for a list of recommended items compared to actual relevant items.

    Args:
        recommended_items (list): List of recommended item IDs.
        actual_relevant_items (set): Set of actual relevant item IDs.
        top_n (int): Number of top recommendations to consider.

    Returns:
        float: NDCG score.
    """
    # Generate relevance scores based on whether recommended items are in the actual relevant set
    relevance_scores = [
        1 if item in actual_relevant_items else 0 for item in recommended_items[:top_n]
    ]

    # Calculate the DCG for recommended items
    actual_dcg = dcg(relevance_scores, top_n)

    # Calculate the ideal DCG for the same number of items
    ideal_relevance_scores = sorted(relevance_scores, reverse=True)
    ideal_dcg = dcg(ideal_relevance_scores, top_n)

    return actual_dcg / ideal_dcg if ideal_dcg > 0 else 0


ndcg_scores = {}
for user_id, recommended_items in tqdm(total_preds.items()):
    actual_relevant_items = set(ratings[ratings["user_id"] == user_id]["item_id"])
    ndcg_scores[user_id] = ndcg(
        recommended_items, get_actual_relevant_items(ratings, user_id), top_n=10
    )

# Calculate the average NDCG across all users
average_ndcg = np.mean(list(ndcg_scores.values()))
print(f"Average NDCG: {average_ndcg}")
# Out:
# 100%|██████████| 99422/99422 [01:28<00:00, 1127.58it/s]
# Average NDCG: 0.0008944304293380125

# %% [markdown]
# ### 5. Diversity in recommendations

# %% [markdown]
# #### Serendipity
#
# The **serendipity** formula based on the provided code is:
#
# $$
# \text{Serendipity}(u) = \frac{1}{|I_r|} \sum_{i \in I_r} \mathbb{I}\left(\text{category}(i) \notin \text{categories}(R_u)\right)
# $$
#
# Where:
# - $I_r$ is the set of recommended items for user $u$.
# - $\text{category}(i)$ is the category of item $i$.
# - $\text{categories}(R_u)$ is the set of categories of the items the user has already interacted with.
# - $\mathbb{I}$ is an indicator function, which returns 1 if the item’s category is different from the user's interacted categories (i.e., the item is **unexpected**), and 0 if it is not.
#
# Serendipity in this context measures how **unexpected** the recommended items are while still being **relevant**. For each item recommended to a user, we check if it belongs to a category that the user has interacted with previously. If the item belongs to a **new** category (i.e., different from the user's previous interactions), it is considered **unexpected**.
#
# - A **higher serendipity score** indicates that the recommendations are more **novel** and surprising, as they introduce items from categories the user hasn't engaged with before.
# - A **lower serendipity score** suggests that the system is recommending items from categories the user is already familiar with, making the recommendations less surprising.
#
# The formula is essentially the proportion of recommendations that are **unexpected**, based on category diversity from the user's past interactions.

# %%
def serendipity(user_id, preds):
    """
    Calculate serendipity of recommendations for certain user
    """
    recommended_items = preds[user_id]

    user_interactions = ratings[ratings["user_id"] == user_id]["item_id"].values
    item_categories = items_data.set_index("item_id")["categories"].to_dict()

    unexpectedness_scores = []
    for item_id in recommended_items:
        if item_id not in user_interactions:
            recommended_category = item_categories.get(item_id)
            interacted_categories = {item_categories.get(i) for i in user_interactions}

            # Measure unexpectedness based on categories
            if recommended_category not in interacted_categories:
                unexpectedness_scores.append(
                    1
                )  # Highly unexpected if it's from a different category
            else:
                unexpectedness_scores.append(
                    0
                )  # Not unexpected if it's from the same category

    return np.mean(unexpectedness_scores)

# %%
user_id = 10
serendipity_val = serendipity(user_id, total_preds)

print(f"Serendipity for user {user_id}: {serendipity_val}")
# Out:
# Serendipity for user 10: 0.9601990049751243

# %%
serend_vals = []
for user_id in tqdm(total_preds.keys()):
    serend_vals.append(serendipity(user_id, total_preds))
# Out:
#   4%|▎         | 3558/99422 [01:44<47:05, 33.93it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-53bac50843fd> in <cell line: 0>()
#       1 serend_vals = []
#       2 for user_id in tqdm(total_preds.keys()):
# ----> 3     serend_vals.append(serendipity(user_id, total_preds))
#
# <ipython-input-78-4118f83f3175> in serendipity(user_id, preds)
#       6
#       7     user_interactions = ratings[ratings["user_id"] == user_id]["item_id"].values
# ----> 8     item_categories = items_data.set_index("item_id")["categories"].to_dict()
#       9
#      10     unexpectedness_scores = []
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in to_dict(self, into)
#    2075
#    2076         if is_object_dtype(self.dtype) or isinstance(self.dtype, ExtensionDtype):
# -> 2077             return into_c((k, maybe_box_native(v)) for k, v in self.items())
#    2078         else:
#    2079             # Not an object dtype => all types will be the same so let the default
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in <genexpr>(.0)
#    2075
#    2076         if is_object_dtype(self.dtype) or isinstance(self.dtype, ExtensionDtype):
# -> 2077             return into_c((k, maybe_box_native(v)) for k, v in self.items())
#    2078         else:
#    2079             # Not an object dtype => all types will be the same so let the default
#
# KeyboardInterrupt:

# %%
plt.hist(serend_vals)
plt.xlabel("serendipity")
plt.ylabel("cnt")
plt.title("Serendipity values")
# Out:
# Text(0.5, 1.0, 'Serendipity values')

# %% [markdown]
# #### Categories sampling

# %% [markdown]
# In real recommendation systems, it is important to add variety to the final recommendations to get rid of the possibility of users falling into a recommendation bubble. Let's make a batch of diverse recommendations!

# %%
def sample_items_by_category(total_preds, item_category, num_samples=3):
    diverse_recs = {}
    category_count = []

    for user_id, preds in tqdm(total_preds.items()):
        category_items = defaultdict(list)

        for item_id in preds:
            category = item_category.get(item_id)
            if category:
                category_items[category].append(item_id)

        # Save number of categories for each user
        category_count.append(len(category_items))

        # Sample items from each category
        sampled_items = []
        for category, items in category_items.items():
            if len(items) > 0:
                sampled = random.sample(items, min(num_samples, len(items)))
                sampled_items.extend(sampled)

        random.shuffle(sampled_items)
        diverse_recs[user_id] = sampled_items

    return diverse_recs, category_count

# %%
diverse_recs, category_count = sample_items_by_category(
    total_preds, items_with_categories
)
# Out:
# 100%|██████████| 99422/99422 [00:12<00:00, 8029.06it/s]

# %%
plt.hist(category_count, bins=10)
plt.xlabel("num_categories")
plt.ylabel("cnt")
plt.title("Category count by users")
# Out:
# Text(0.5, 1.0, 'Category count by users')

# %% [markdown]
# Now, let's calculate IoU for top10 recommendations to compare with baseline (category-based) recommendations:

# %%
top_n = 10

categories = items_data["categories"].unique()
category_to_index = {category: i for i, category in enumerate(categories)}

iou_scores = []

for user in tqdm(ratings["user_id"].unique()):
    rec_item_ids = diverse_recs[user]

    rec_categories = set(
        items_data[items_data["item_id"].isin(rec_item_ids)]["categories"]
    )
    rec_vector = [1 if category in rec_categories else 0 for category in categories]

    # Get category-based recommendations (as a baseline)
    user_interacted_item_ids = ratings[ratings["user_id"] == user]["item_id"].unique()
    user_interacted_categories = set(
        items_data[items_data["item_id"].isin(user_interacted_item_ids)]["categories"]
    )
    baseline_recommendations = items_data[
        items_data["categories"].isin(user_interacted_categories)
    ]

    if len(baseline_recommendations) > top_n:
        baseline_recommendations = baseline_recommendations.sample(top_n, replace=False)
    baseline_categories = set(baseline_recommendations["categories"])

    baseline_vector = [
        1 if category in baseline_categories else 0 for category in categories
    ]

    # Calculate IoU (Jaccard similarity) between the two vectors
    iou_score = jaccard_score(rec_vector, baseline_vector)
    iou_scores.append(iou_score)

iou_df = pd.DataFrame({"user_id": ratings["user_id"].unique(), "iou_score": iou_scores})
# Out:
# 100%|██████████| 99422/99422 [09:46<00:00, 169.39it/s]

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=iou_df, x="iou_score")
plt.title(
    "IoU score distribution between total recommendations and category-based recommendations"
)
plt.xlabel("IoU Score")
plt.ylabel("Density")
plt.show()
